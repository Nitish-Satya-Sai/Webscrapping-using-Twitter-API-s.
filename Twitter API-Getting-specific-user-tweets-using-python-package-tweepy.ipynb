# %%
import tweepy
import configparser
import pandas as pd

# %%
conobj=configparser.ConfigParser()
conobj.read("config.ini")
api_key = conobj["bluebird"]["API_Key"]
api_key_secret = conobj["bluebird"]["API_Key_Secret"]
access_token = conobj["bluebird"]["ACCESS_TOKEN"]
access_token_secret = conobj["bluebird"]["ACCESS_TOKEN_SECRET"]

# %%
auth=tweepy.OAuthHandler(api_key,api_key_secret)
auth.set_access_token(access_token,access_token_secret)
api=tweepy.API(auth)

# %%
user="elonmusk"
tm="extended"
limit=300
tweets = tweepy.Cursor(api.user_timeline,
              screen_name = user,tweet_mode=tm).items(limit)

# %%
data=[]
columns = ["Timeline","User","tweet"]
for tweet in tweets:
    data.append([tweet.created_at,tweet.user.screen_name,tweet.full_text])
    
df_user_data=pd.DataFrame(data,columns=columns)

# %%
df_user_data
# Out:
#                      Timeline      User  \
# 0   2022-09-12 05:44:11+00:00  elonmusk
# 1   2022-09-12 05:43:02+00:00  elonmusk
# 2   2022-09-12 04:19:57+00:00  elonmusk
# 3   2022-09-12 03:25:03+00:00  elonmusk
# 4   2022-09-12 01:48:49+00:00  elonmusk
# ..                        ...       ...
# 295 2022-08-06 20:58:02+00:00  elonmusk
# 296 2022-08-06 20:55:54+00:00  elonmusk
# 297 2022-08-06 20:51:30+00:00  elonmusk
# 298 2022-08-06 16:20:33+00:00  elonmusk
# 299 2022-08-06 16:18:59+00:00  elonmusk
#
#                                                  tweet
# 0    @teslaownersSV @cb_doge @Tesla @mayemusk I gue...
# 1    @cb_doge @Tesla @mayemusk Still doing same thi...
# 2    Looks good to roll out to all Tesla owners wit...
# 3    @Tesla__Mania @WholeMarsBlog That is probably ...
# 4    @WholeMarsBlog Real-world validation &amp; bil...
# ..                                                 ...
# 295  @truth_tesla @brettlindquist @garyblack00 Yeah...
# 296                                 @cb_doge @paraga 🤣
# 297           Saxon James Musk https://t.co/d7FKw4iQIU
# 298                                         @cb_doge 💯
# 299  Less than 5% of Twitter daily users are fake/spam
#
# [300 rows x 3 columns]

# %%
df_user_data.head(30)
# Out:
#                     Timeline      User  \
# 0  2022-09-12 05:44:11+00:00  elonmusk
# 1  2022-09-12 05:43:02+00:00  elonmusk
# 2  2022-09-12 04:19:57+00:00  elonmusk
# 3  2022-09-12 03:25:03+00:00  elonmusk
# 4  2022-09-12 01:48:49+00:00  elonmusk
# 5  2022-09-12 01:20:59+00:00  elonmusk
# 6  2022-09-11 21:34:12+00:00  elonmusk
# 7  2022-09-11 21:31:34+00:00  elonmusk
# 8  2022-09-11 03:00:14+00:00  elonmusk
# 9  2022-09-11 02:29:13+00:00  elonmusk
# 10 2022-09-11 00:11:00+00:00  elonmusk
# 11 2022-09-10 21:09:13+00:00  elonmusk
# 12 2022-09-10 20:46:49+00:00  elonmusk
# 13 2022-09-10 17:20:36+00:00  elonmusk
# 14 2022-09-10 17:08:35+00:00  elonmusk
# 15 2022-09-10 17:01:49+00:00  elonmusk
# 16 2022-09-10 17:00:13+00:00  elonmusk
# 17 2022-09-10 01:50:49+00:00  elonmusk
# 18 2022-09-10 01:09:38+00:00  elonmusk
# 19 2022-09-09 23:52:33+00:00  elonmusk
# 20 2022-09-09 23:40:48+00:00  elonmusk
# 21 2022-09-09 22:32:27+00:00  elonmusk
# 22 2022-09-09 22:29:06+00:00  elonmusk
# 23 2022-09-09 22:22:27+00:00  elonmusk
# 24 2022-09-09 22:19:06+00:00  elonmusk
# 25 2022-09-09 21:49:28+00:00  elonmusk
# 26 2022-09-09 21:06:17+00:00  elonmusk
# 27 2022-09-09 19:03:38+00:00  elonmusk
# 28 2022-09-09 04:15:27+00:00  elonmusk
# 29 2022-09-08 23:26:39+00:00  elonmusk
#
#                                                 tweet
# 0   @teslaownersSV @cb_doge @Tesla @mayemusk I gue...
# 1   @cb_doge @Tesla @mayemusk Still doing same thi...
# 2   Looks good to roll out to all Tesla owners wit...
# 3   @Tesla__Mania @WholeMarsBlog That is probably ...
# 4   @WholeMarsBlog Real-world validation &amp; bil...
# 5                       @Teslarati @JohnnaCrider1 Yup
# 6                               @cb_doge @paraga Sigh
# 7   FSD Beta 10.69.2 rolling out now. Please note ...
# 8     Falcon arching to orbit https://t.co/m7grug8FV9
# 9   No obvious limit to rocket reflight so far htt...
# 10             @Austen Instagram is an envy amplifier
# 11                     @DirtyTesLa @WholeMarsBlog Yes
# 12  @WholeMarsBlog Team found a bug causing an 8% ...
# 13                                        @EvaFoxU 🔥🤣
# 14  @chicago_glenn @stevenmarkryan @WholeMarsBlog ...
# 15                @stevenmarkryan @WholeMarsBlog Haha
# 16                                      Astronomy too
# 17  @WholeMarsBlog Internal beta rollout tonight, ...
# 18                        @WholeMarsBlog It’s coming!
# 19   Take Materials Science 101. You won’t regret it.
# 20              A major Fed rate hike risks deflation
# 21           @_bennettm_ Please lmk when that happens
# 22  @TeslaGong Absolutely, the Tesla fleet in Aust...
# 23  Tesla North America aiming for &gt;50% same ho...
# 24                                          @andst7 🤣
# 25     @EvaFoxU @cb_doge @BillyM2k @cz_binance Anubis
# 26  @BillyM2k @cz_binance Nice. I’m dressing up as...
# 27           @SpaceX One of our most complex missions
# 28           @EvasTeslaSPlaid @paraga Bot block party
# 29  @CodingMark @Andy8671025 @WholeMarsBlog Assumi...
